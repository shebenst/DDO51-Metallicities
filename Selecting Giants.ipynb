# %%
#Import all data and set fits as variables
from astropy.io import fits
import numpy as np
spec = fits.getdata(r'C:\Users\shebe\OneDrive\School\Graduate\Research\Fall 2017\Data\Ho2017_Catalog.fits',1)
spec2 = fits.getdata(r'C:\Users\shebe\OneDrive\School\Graduate\Research\Fall 2017\Data\ssppOut-dr10.fits.gz',1)

# %%
#Making cuts in data

#Create matrix
mat=[list(a) for a in zip(spec2['LOGG_ADOP'],spec2['TEFF_ADOP'])]
mat=np.array(mat)
#data=mat

#Horizontal cut at log(g)=3.8, diagonal cut, and cutting out aberrant values
data=mat[(mat[:,0] < 3.8) 
         & (mat[:,0]>0)
         & (mat[:,1]>4050)
         & (mat[:,1]<5875)
         & (((mat[:,0]-1.86)/(mat[:,1]-4035))<0.00345)
        ]

# %%
#Plotting logg vs Teff for sspp data
# %matplotlib nbagg
import matplotlib.pyplot as plt
y=data[:,0]
x=data[:,1]

#plt.figure(figsize=(18,18))
plt.scatter(x,y,marker='+',c='blue',s=3)
plt.xlabel('Teff',fontsize=15)
plt.ylabel('log(g)',rotation='horizontal',labelpad=25,fontsize=18)
#plt.xlim(3000,7000)
#plt.ylim(0,6)
plt.figsize=(18,16)

ax=plt.gca()
ax.invert_xaxis()
ax.invert_yaxis()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
